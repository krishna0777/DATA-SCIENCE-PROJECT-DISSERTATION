# %% [markdown]
# # IMPORTING GOOGLE DRIVE TO WORK WITH COLAB

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/Dataset/
import os
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/Dataset

# %%
# %cd "/content/drive/MyDrive/Dataset_Extracted"
# Out:
# /content/drive/MyDrive/Dataset_Extracted

# %% [markdown]
# # MAKING DIRECTORIES AND UNZIPPING TO RESPECTIVE LOCATIONS

# %%
# !mkdir train_data
# !mkdir test_data
# !mkdir dev_data

# %%
import numpy as np
import pandas as pd

dev = np.array(pd.read_csv('/content/drive/MyDrive/Dataset/dev_split_Depression_AVEC2017.csv',delimiter=',',encoding='utf-8'))[:, 0:2]
test = np.array(pd.read_csv('/content/drive/MyDrive/Dataset/full_test_split.csv',delimiter=',',encoding='utf-8'))[:, 0:2]
train = np.array(pd.read_csv('/content/drive/MyDrive/Dataset/train_split_Depression_AVEC2017.csv',delimiter=',',encoding='utf-8'))[:, 0:2]

for i in range(len(dev)):
    s = "/content/drive/MyDrive/Dataset/" + str(int(dev[i][0])) + "_P.zip"
    # !unzip -q {s} -d dev_data

for i in range(len(test)):
    s = "/content/drive/MyDrive/Dataset/" + str(int(test[i][0])) + "_P.zip"
    # !unzip -q {s} -d test_data

for i in range(len(train)):
    s = "/content/drive/MyDrive/Dataset/" + str(int(train[i][0])) + "_P.zip"
    # !unzip -q {s} -d train_data
